# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
from keras.layers.normalization import BatchNormalization
import h5py
# %matplotlib inline

# %%
# 자신이 설정하는 파라미터

# 배치사이즈
batch_size = 2000

# 에포크수
epochs = 100

# %%
# 데이터 추출
(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = 10
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# one-hot-label에 변환
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 60000 train samples
# 10000 test samples

# %%
# 모델의 구축
model = Sequential()

# 첫번째 히든 레이어(입력784 -> 출력256)
model.add(Dense(256, activation="relu",input_shape=(784,)))
model.add(Dropout(0.1))

# 두번째 히든 레이어(256 -> 출력128)
## 히든레이어는 아래의 두행을 복사->붙여넣기하는 것으로 추가할 수 있습니다.
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))

# 3번째 히든 레이어(128 -> 출력32)
## 隠れ層は以下の2行をコピペすることで追加できます
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))

# 출력 레이어力層(입력32 -> 출력10)
model.add(Dense(10, activation='softmax'))

# 모델 개요 표시
model.summary()

# 모델의 컴파일モ
model.compile(loss='categorical_crossentropy',
              optimizer='SGD',
              metrics=['accuracy'])

# 피팅(학습)
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

# 스코어의 계산과 표시
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# =================================================================
# Total params: 238,314
# Trainable params: 238,314
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 30/30 [==============================] - 1s 30ms/step - loss: 2.3048 - accuracy: 0.1138 - val_loss: 2.2469 - val_accuracy: 0.1552
# Epoch 2/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.2242 - accuracy: 0.1822 - val_loss: 2.1620 - val_accuracy: 0.2827
# Epoch 3/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.1430 - accuracy: 0.2769 - val_loss: 2.0632 - val_accuracy: 0.4397
# Epoch 4/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.0473 - accuracy: 0.3742 - val_loss: 1.9459 - val_accuracy: 0.5636
# Epoch 5/100
# 30/30 [==============================] - 1s 22ms/step - loss: 1.9367 - accuracy: 0.4576 - val_loss: 1.8137 - val_accuracy: 0.6315
# Epoch 6/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8134 - accuracy: 0.5177 - val_loss: 1.6690 - val_accuracy: 0.6793
# Epoch 7/100
# 30/30 [==============================] - 1s 23ms/step - loss: 1.6833 - accuracy: 0.5656 - val_loss: 1.5179 - val_accuracy: 0.7104
# Epoch 8/100
# 30/30 [==============================] - 1s 23ms/step - loss: 1.5505 - accuracy: 0.6041 - val_loss: 1.3678 - val_accuracy: 0.7394
# Epoch 9/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4249 - accuracy: 0.6378 - val_loss: 1.2258 - val_accuracy: 0.7670
# Epoch 10/100
# 30/30 [==============================] - 1s 18ms/step - loss: 1.3099 - accuracy: 0.6620 - val_loss: 1.0969 - val_accuracy: 0.7902
# Epoch 11/100
# 30/30 [==============================] - 1s 17ms/step - loss: 1.2029 - accuracy: 0.6845 - val_loss: 0.9839 - val_accuracy: 0.8075
# Epoch 12/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1100 - accuracy: 0.7038 - val_loss: 0.8886 - val_accuracy: 0.8195
# Epoch 13/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.0362 - accuracy: 0.7177 - val_loss: 0.8105 - val_accuracy: 0.8279
# Epoch 14/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.9690 - accuracy: 0.7290 - val_loss: 0.7455 - val_accuracy: 0.8372
# Epoch 15/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.9098 - accuracy: 0.7432 - val_loss: 0.6919 - val_accuracy: 0.8444
# Epoch 16/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.8620 - accuracy: 0.7532 - val_loss: 0.6483 - val_accuracy: 0.8503
# Epoch 17/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.8240 - accuracy: 0.7627 - val_loss: 0.6114 - val_accuracy: 0.8573
# Epoch 18/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0
# 30/30 [==============================] - 1s 24ms/step - loss: 0.4721 - accuracy: 0.8598 - val_loss: 0.3360 - val_accuracy: 0.9063
# Epoch 46/100
# 30/30 [==============================] - 1s 25ms/step - loss: 0.4703 - accuracy: 0.8594 - val_loss: 0.3331 - val_accuracy: 0.9078
# Epoch 47/100
# 30/30 [==============================] - 1s 25ms/step - loss: 0.4617 - accuracy: 0.8640 - val_loss: 0.3295 - val_accuracy: 0.9079
# Epoch 48/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4605 - accuracy: 0.8651 - val_loss: 0.3267 - val_accuracy: 0.9083
# Epoch 49/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.4565 - accuracy: 0.8653 - val_loss: 0.3237 - val_accuracy: 0.9097
# Epoch 50/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4487 - accuracy: 0.8679 - val_loss: 0.3209 - val_accuracy: 0.9099
# Epoch 51/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4455 - accuracy: 0.8674 - val_loss: 0.3179 - val_accuracy: 0.9111
# Epoch 52/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4452 - accuracy: 0.8698 - val_loss: 0.3154 - val_accuracy: 0.9116
# Epoch 53/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4411 - accuracy: 0.8683 - val_loss: 0.3130 - val_accuracy: 0.9122
# Epoch 54/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.4343 - accuracy: 0.8728 - val_loss: 0.3101 - val_accuracy: 0.9125
# Epoch 55/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4331 - accuracy: 0.8732 - val_loss: 0.3075 - val_accuracy: 0.9131
# Epoch 56/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4295 - accuracy: 0.8732 - val_loss: 0.3054 - val_accuracy: 0.9134
# Epoch 57/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4256 - accuracy: 0.8743 - val_loss: 0.3030 - val_accuracy: 0.9138
# Epoch 58/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4199 - accuracy: 0.8767 - val_loss: 0.3006 - val_accuracy: 0.9142
# Epoch 59/100
# 30/30 [==============================] - 1s 24ms/step - loss: 0.4172 - accuracy: 0.8780 - val_loss: 0.2983 - val_accuracy: 0.9148
# Epoch 60/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.4166 - accuracy: 0.8789 - val_loss: 0.2964 - val_accuracy: 0.9162
# Epoch 61/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4093 - accuracy: 0.8795 - val_loss: 0.2939 - val_accuracy: 0.9164
# Epoch 62/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4085 - accuracy: 0.8807 - val_loss: 0.2918 - val_accuracy: 0.9173
# Epoch 63/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.4052 - accuracy: 0.8816 - val_loss: 0.2898 - val_accuracy: 0.9175
# Epoch 64/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4005 - accuracy: 0.8809 - val_loss: 0.2879 - val_accuracy: 0.9185
# Epoch 65/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3963 - accuracy: 0.8844 - val_loss: 0.2861 - val_accuracy: 0.9189
# Epoch 66/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3967 - accuracy: 0.8844 - val_loss: 0.2842 - val_accuracy: 0.9187
# Epoch 67/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3943 - accuracy: 0.8848 - val_loss: 0.2820 - val_accuracy: 0.9193
# Epoch 68/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3928 - accuracy: 0.8849 - val_loss: 0.2803 - val_accuracy: 0.9196
# Epoch 69/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3907 - accuracy: 0.8857 - val_loss: 0.2784 - val_accuracy: 0.9201
# Epoch 70/100
# 30/30 [==============================] - 1s 24ms/step - loss: 0.3863 - accuracy: 0.8850 - val_loss: 0.2768 - val_accuracy: 0.9206
# Epoch 71/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3841 - accuracy: 0.8883 - val_loss: 0.2752 - val_accuracy: 0.9212
# Epoch 72/100
# 30/30 [==============================] - 1s 25ms/step - loss: 0.3812 - accuracy: 0.8896 - val_loss: 0.2733 - val_accuracy: 0.9217
# Epoch 73/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3805 - accuracy: 0.8885 - val_loss: 0.2714 - val_accuracy: 0.9222
# Epoch 74/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3782 - accuracy: 0.8899 - val_loss: 0.2700 - val_accuracy: 0.9227
# Epoch 75/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3717 - accuracy: 0.8909 - val_loss: 0.2684 - val_accuracy: 0.9227
# Epoch 76/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3698 - accuracy: 0.8916 - val_loss: 0.2666 - val_accuracy: 0.9230
# Epoch 77/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3681 - accuracy: 0.8928 - val_loss: 0.2651 - val_accuracy: 0.9238
# Epoch 78/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3668 - accuracy: 0.8936 - val_loss: 0.2634 - val_accuracy: 0.9237
# Epoch 79/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3630 - accuracy: 0.8940 - val_loss: 0.2618 - val_accuracy: 0.9240
# Epoch 80/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3660 - accuracy: 0.8929 - val_loss: 0.2603 - val_accuracy: 0.9245
# Epoch 81/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3616 - accuracy: 0.8955 - val_loss: 0.2590 - val_accuracy: 0.9249
# Epoch 82/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3578 - accuracy: 0.8950 - val_loss: 0.2575 - val_accuracy: 0.9254
# Epoch 83/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3569 - accuracy: 0.8964 - val_loss: 0.2561 - val_accuracy: 0.9260
# Epoch 84/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3564 - accuracy: 0.8954 - val_loss: 0.2549 - val_accuracy: 0.9259
# Epoch 85/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3522 - accuracy: 0.8967 - val_loss: 0.2535 - val_accuracy: 0.9261
# Epoch 86/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3510 - accuracy: 0.8972 - val_loss: 0.2519 - val_accuracy: 0.9263
# Epoch 87/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3503 - accuracy: 0.8966 - val_loss: 0.2508 - val_accuracy: 0.9268
# Epoch 88/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3468 - accuracy: 0.8985 - val_loss: 0.2494 - val_accuracy: 0.9273
# Epoch 89/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3477 - accuracy: 0.8993 - val_loss: 0.2479 - val_accuracy: 0.9280
# Epoch 90/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3398 - accuracy: 0.9009 - val_loss: 0.2469 - val_accuracy: 0.9279
# Epoch 91/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3434 - accuracy: 0.8997 - val_loss: 0.2454 - val_accuracy: 0.9285
# Epoch 92/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3382 - accuracy: 0.9013 - val_loss: 0.2442 - val_accuracy: 0.9285
# Epoch 93/100
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3385 - accuracy: 0.9001 - val_loss: 0.2431 - val_accuracy: 0.9289
# Epoch 94/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3359 - accuracy: 0.9021 - val_loss: 0.2416 - val_accuracy: 0.9296
# Epoch 95/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3352 - accuracy: 0.9028 - val_loss: 0.2404 - val_accuracy: 0.9295
# Epoch 96/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3345 - accuracy: 0.9023 - val_loss: 0.2392 - val_accuracy: 0.9299
# Epoch 97/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3300 - accuracy: 0.9038 - val_loss: 0.2381 - val_accuracy: 0.9301
# Epoch 98/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3278 - accuracy: 0.9040 - val_loss: 0.2369 - val_accuracy: 0.9310
# Epoch 99/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3262 - accuracy: 0.9051 - val_loss: 0.2358 - val_accuracy: 0.9311
# Epoch 100/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3272 - accuracy: 0.9055 - val_loss: 0.2347 - val_accuracy: 0.9315
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9315
# Test loss: 0.2346988022327423
# Test accuracy: 0.9315000176429749

# %%
model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9315
# [0.2346988022327423, 0.9315000176429749]

# %%
# 학습의 결과를 플롯
loss = history.history['loss']
val_loss = history.history['val_loss']

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.title('Loss')
epochs = len(loss)
plt.plot(range(epochs), loss, marker='.', label='loss')
plt.plot(range(epochs), val_loss, marker='.', label='val_loss')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')

plt.subplot(2,1,2)
plt.title('Accuracy')
plt.plot(range(epochs), acc, marker='.', label='acc')
plt.plot(range(epochs), val_acc, marker='.', label='val_acc')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()
